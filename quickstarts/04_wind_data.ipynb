# %% [markdown]
# <a href="https://colab.research.google.com/github/STASYA00/IAAC2024_tutorials/blob/main/quickstarts/03_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> - Stasja's notebook

# %%
# !pip install ipykernel plotly nbformat>4.2.0

# %%
# !pip install --upgrade nbformat

# %% [markdown]
# * [Ortools package](https://developers.google.com/optimization)
# * [What is optimization](https://en.wikipedia.org/wiki/Mathematical_optimization)
# * [Video on what optimization is](https://youtu.be/AM6BY4btj-M?t=170&si=FUAW-bzml27y61zq) - only 2.50 - 6.00

# %% [markdown]
# ## 💨 Wind data

# %% [markdown]
# ### Ecad data

# %% [markdown]
# One of the possible sources is [Ecad data](https://www.ecad.eu/dailydata/customquery.php).
#
# Steps:
# * Go to custom query in ECAD
# * Select __Wind direction__ in the _third_ dropdown
# * Choose from the countries with available wind direction data
# * Choose from the available stations in the selected country
# * Download the file and unzip it
#
# You can get climate data elsewhere, for example, from [YR](https://developer.yr.no/doc/GettingStarted/)

# %%
import pandas as pd

FILEPATH = "../.assets/wind_jan_mayen.csv"
df = pd.read_csv(FILEPATH, skipinitialspace = True)
df
# Out:
#       STAID   SOUID      DATE    DD  Q_DD
# 0       189  114683  20090901   348     0
# 1       189  114683  20090902   347     0
# 2       189  114683  20090903   310     0
# 3       189  114683  20090904   331     0
# 4       189  114683  20090905   330     0
# ...     ...     ...       ...   ...   ...
# 5321    189  114683  20240327 -9999     9
# 5322    189  114683  20240328 -9999     9
# 5323    189  114683  20240329 -9999     9
# 5324    189  114683  20240330 -9999     9
# 5325    189  114683  20240331 -9999     9
#
# [5326 rows x 5 columns]

# %%
FILEPATH = "../.assets/wind_speed_jan_mayen.txt"
df_speed = pd.read_csv(FILEPATH, skipinitialspace = True, skiprows=18)
df_speed.head()
# Out:
#     SOUID      DATE   FG  Q_FG
# 0  114682  19790101   15     1
# 1  114682  19790102  110     1
# 2  114682  19790103  163     1
# 3  114682  19790104  164     1
# 4  114682  19790105   70     1

# %% [markdown]
# Let's merge our dataframes by date and remove the missing values. In the datasets' descriptions you will see that missing values correspond to value 9 in "Q_ " column. Let's filter out these values.

# %%
full_df = df.merge(df_speed, how="left", on=["DATE"])  # merging two dataframes by date

full_df = full_df.loc[full_df["Q_DD"]!=9].loc[full_df["Q_FG"]!=9]  # remove all missing observations
full_df.head()
# Out:
#    STAID  SOUID_x      DATE   DD  Q_DD   SOUID_y     FG  Q_FG
# 0    189   114683  20090901  348     0  114682.0   88.0   0.0
# 1    189   114683  20090902  347     0  114682.0  112.0   0.0
# 2    189   114683  20090903  310     0  114682.0   70.0   0.0
# 3    189   114683  20090904  331     0  114682.0   59.0   0.0
# 4    189   114683  20090905  330     0  114682.0   33.0   0.0

# %%
full_df = full_df[["DATE", "DD", "FG"]]  # leave only relevant columns

full_df["DATE"] = pd.to_datetime(full_df["DATE"], format="%Y%m%d")  # convert DATE column to datetime format

full_df.head()
# Out:
#         DATE   DD     FG
# 0 2009-09-01  348   88.0
# 1 2009-09-02  347  112.0
# 2 2009-09-03  310   70.0
# 3 2009-09-04  331   59.0
# 4 2009-09-05  330   33.0

# %%
full_df["season"] = full_df["DATE"].apply(lambda s: s.month // 3)
full_df["month"] = full_df["DATE"].apply(lambda s: s.month)

# %% [markdown]
# ### Visualizing wind data

# %%
import plotly.express as px

fig = px.bar_polar(full_df, r="FG", theta="DD",
                  #  color="FG",
                     template="plotly_dark",
                   color_discrete_sequence= px.colors.sequential.Plasma_r)
fig.show()
# Out:
# <div>                            <div id="0b7af575-0d8e-4de3-bb7c-e4e764246e67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b7af575-0d8e-4de3-bb7c-e4e764246e67")) {                    Plotly.newPlot(                        "0b7af575-0d8e-4de3-bb7c-e4e764246e67",                        [{"hovertemplate":"FG=%{r}\u003cbr\u003eDD=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#f0f921","pattern":{"shape":""}},"name":"","r":[88.0,112.0,70.0,59.0,33.0,25.0,18.0,26.0,58.0,28.0,57.0,33.0,71.0,29.0,60.0,58.0,65.0,40.0,37.0,77.0,94.0,106.0,32.0,79.0,53.0,57.0,58.0,96.0,48.0,84.0,94.0,82.0,86.0,73.0,39.0,76.0,86.0,92.0,66.0,78.0,73.0,39.0,90.0,71.0,78.0,44.0,98.0,66.0,99.0,63.0,34.0,53.0,74.0,150.0,141.0,122.0,68.0,54.0,52.0,27.0,50.0,65.0,16.0,81.0,85.0,64.0,35.0,50.0,93.0,57.0,93.0,54.0,79.0,37.0,95.0,132.0,123.0,126.0,45.0,53.0,82.0,100.0,136.0,155.0,124.0,114.0,124.0,115.0,137.0,137.0,96.0,53.0,48.0,72.0,61.0,82.0,36.0,59.0,56.0,34.0,20.0,19.0,36.0,43.0,92.0,50.0,114.0,95.0,137.0,100.0,121.0,137.0,112.0,107.0,91.0,68.0,88.0,81.0,98.0,76.0,39.0,35.0,91.0,84.0,93.0,33.0,40.0,58.0,61.0,114.0,87.0,68.0,65.0,35.0,66.0,58.0,44.0,57.0,71.0,49.0,63.0,76.0,69.0,58.0,36.0,85.0,92.0,142.0,99.0,113.0,110.0,85.0,87.0,71.0,92.0,33.0,24.0,51.0,47.0,22.0,58.0,30.0,38.0,80.0,72.0,57.0,78.0,74.0,83.0,68.0,79.0,62.0,99.0,71.0,108.0,133.0,123.0,75.0,79.0,43.0,54.0,26.0,31.0,52.0,56.0,97.0,76.0,68.0,60.0,61.0,65.0,57.0,79.0,80.0,56.0,31.0,45.0,47.0,99.0,112.0,73.0,82.0,81.0,77.0,51.0,57.0,62.0,105.0,115.0,100.0,86.0,98.0,97.0,39.0,38.0,26.0,81.0,74.0,68.0,30.0,35.0,76.0,49.0,34.0,79.0,83.0,76.0,74.0,55.0,84.0,76.0,78.0,50.0,46.0,94.0,92.0,70.0,50.0,53.0,59.0,61.0,55.0,72.0,61.0,54.0,28.0,76.0,60.0,83.0,95.0,102.0,43.0,37.0,55.0,34.0,40.0,29.0,59.0,113.0,31.0,54.0,55.0,43.0,98.0,122.0,136.0,69.0,45.0,47.0,43.0,52.0,43.0,48.0,77.0,30.0,26.0,17.0,19.0,30.0,32.0,28.0,19.0,49.0,69.0,26.0,35.0,20.0,41.0,96.0,65.0,28.0,20.0,50.0,57.0,24.0,49.0,77.0,84.0,88.0,92.0,51.0,29.0,18.0,46.0,68.0,18.0,11.0,46.0,50.0,28.0,16.0,15.0,29.0,25.0,32.0,24.0,47.0,21.0,15.0,96.0,84.0,47.0,39.0,51.0,25.0,32.0,24.0,25.0,20.0,18.0,31.0,19.0,66.0,21.0,16.0,14.0,24.0,15.0,20.0,27.0,50.0,32.0,50.0,51.0,67.0,20.0,67.0,35.0,44.0,50.0,61.0,49.0,76.0,60.0,76.0,48.0,34.0,27.0,22.0,25.0,30.0,49.0,62.0,43.0,38.0,32.0,30.0,23.0,40.0,37.0,38.0,32.0,22.0,55.0,57.0,56.0,62.0,96.0,96.0,110.0,127.0,112.0,97.0,107.0,87.0,63.0,61.0,27.0,61.0,29.0,79.0,58.0,49.0,56.0,30.0,66.0,56.0,42.0,58.0,59.0,66.0,44.0,45.0,49.0,52.0,68.0,49.0,39.0,31.0,40.0,86.0,135.0,92.0,123.0,139.0,93.0,88.0,96.0,67.0,59.0,118.0,51.0,56.0,81.0,112.0,64.0,126.0,131.0,95.0,86.0,65.0,25.0,42.0,57.0,77.0,168.0,97.0,126.0,57.0,79.0,62.0,122.0,66.0,17.0,25.0,51.0,22.0,60.0,81.0,122.0,62.0,45.0,37.0,83.0,40.0,79.0,94.0,95.0,112.0,109.0,88.0,98.0,85.0,56.0,21.0,56.0,44.0,17.0,84.0,102.0,144.0,126.0,105.0,128.0,94.0,73.0,80.0,26.0,24.0,21.0,50.0,89.0,47.0,58.0,90.0,121.0,68.0,54.0,66.0,129.0,121.0,215.0,162.0,86.0,125.0,115.0,103.0,77.0,59.0,63.0,130.0,84.0,125.0,133.0,73.0,58.0,74.0,43.0,65.0,73.0,109.0,122.0,118.0,52.0,84.0,67.0,85.0,108.0,105.0,100.0,48.0,50.0,72.0,85.0,67.0,54.0,93.0,71.0,64.0,52.0,77.0,83.0,51.0,48.0,27.0,35.0,56.0,110.0,62.0,56.0,66.0,55.0,92.0,76.0,87.0,112.0,111.0,90.0,100.0,65.0,109.0,102.0,99.0,128.0,170.0,155.0,68.0,48.0,107.0,113.0,103.0,115.0,79.0,119.0,57.0,54.0,71.0,72.0,104.0,23.0,41.0,75.0,68.0,33.0,47.0,17.0,51.0,69.0,84.0,60.0,66.0,74.0,22.0,115.0,65.0,84.0,85.0,38.0,31.0,34.0,97.0,74.0,56.0,71.0,122.0,84.0,78.0,37.0,41.0,54.0,76.0,101.0,29.0,45.0,42.0,27.0,52.0,51.0,97.0,51.0,26.0,26.0,21.0,27.0,75.0,27.0,16.0,16.0,21.0,41.0,39.0,42.0,30.0,55.0,104.0,67.0,109.0,108.0,140.0,125.0,83.0,48.0,33.0,66.0,97.0,121.0,78.0,36.0,3 ...
